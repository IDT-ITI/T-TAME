# %%
import torch

# %%
checkpoint = torch.load("/home/ntrougkas/Documents/T-TAME/old models/resnet tame/epoch_4.pt")

# %%
print(checkpoint)
# Out:
# {'epoch': 4, 'global_counter': 640584, 'state_dict': OrderedDict([('attn.convs.0.weight', tensor([[[[ 0.0169]],
#
#          [[ 0.0015]],
#
#          [[-0.0115]],
#
#          ...,
#
#          [[-0.0033]],
#
#          [[-0.0141]],
#
#          [[ 0.0005]]],
#
#
#         [[[ 0.0082]],
#
#          [[-0.0283]],
#
#          [[-0.0007]],
#
#          ...,
#
#          [[-0.0067]],
#
#          [[-0.0003]],
#
#          [[ 0.0042]]],
#
#
#         [[[ 0.0372]],
#
#          [[ 0.0023]],
#
#          [[-0.0200]],
#
#          ...,
#
#          [[ 0.0153]],
#
#          [[-0.0030]],
#
#          [[-0.0144]]],
#
#
#         ...,
#
#
#         [[[ 0.0178]],
#
#          [[-0.0038]],
#
#          [[-0.0048]],
#
#          ...,
#
#          [[ 0.0005]],
#
#          [[ 0.0054]],
#
#          [[-0.0036]]],
#
#
#         [[[ 0.0424]],
#
#          [[ 0.0079]],
#
#          [[ 0.0098]],
#
#          ...,
#
#          [[-0.0074]],
#
#          [[-0.0023]],
#
#          [[-0.0106]]],
#
#
# ...
